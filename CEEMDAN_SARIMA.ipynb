# %% [markdown]
# <a href="https://colab.research.google.com/github/DanellaVentinuaryInnocent/test1/blob/main/CEEMDAN_SARIMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Instalasi library python**

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install EMD-signal
# !pip install scikit-learn
# !pip install tensorflow

# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 72.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 86.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Membuat file**

# %%
# %%writefile CEEMDAN-SARIMA.py
# Out:
# Writing CEEMDAN-SARIMA.py

# %% [markdown]
# ### **menampilkan IP**

# %%
! wget -q -O - ipv4.icanhazip.com
# Out:
# 34.30.243.180

# %% [markdown]
# ### **Menjalankan kodingan**

# %%
! streamlit run CEEMDAN-SARIMA.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙⠹⠸⠼⠴
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.2:8501
#   External URL: http://34.30.243.180:8501
#
# ⠦⠧Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼your url is: https://busy-trams-listen.loca.lt
# 2025-05-03 00:14:02.173 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 557, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
